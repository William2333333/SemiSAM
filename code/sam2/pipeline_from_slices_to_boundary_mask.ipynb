# %%
import os
print(os.getcwd())

# %%
import os
import numpy as np
import torch
import cv2
import matplotlib.pyplot as plt
from sam2.build_sam import build_sam2
from sam2.automatic_mask_generator import SAM2AutomaticMaskGenerator
import skimage
from PIL import Image

BASE_DIR = os.getcwd()

input_dir = os.path.join(BASE_DIR,"../data/samples_preprocessed/interpolated_images_resized")
output_dir = os.path.join(BASE_DIR,"../test_SAM/SAM_2_ORI_second_inference/Hiera_l")
os.makedirs(output_dir,exist_ok= True)

patient_id = "019288-01"
sam2_checkpoint = os.path.join(BASE_DIR,"checkpoints/sam2.1_hiera_large.pt")
model_cfg = "configs/sam2.1/sam2.1_hiera_l"


# select the device for computation
if torch.cuda.is_available():
    device = torch.device("cuda")
elif torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")
print(f"using device: {device}")
if device.type == "cuda":
    # use bfloat16 for the entire notebook
    torch.autocast("cuda", dtype=torch.bfloat16).__enter__()
    # turn on tfloat32 for Ampere GPUs (https://pytorch.org/docs/stable/notes/cuda.html#tensorfloat-32-tf32-on-ampere-devices)
    if torch.cuda.get_device_properties(0).major >= 8:
        torch.backends.cuda.matmul.allow_tf32 = True
        torch.backends.cudnn.allow_tf32 = True
elif device.type == "mps":
    print(
        "\nSupport for MPS devices is preliminary. SAM 2 is trained with CUDA and might "
        "give numerically different outputs and sometimes degraded performance on MPS. "
        "See e.g. https://github.com/pytorch/pytorch/issues/84936 for a discussion."
    )
sam2 = build_sam2(model_cfg, sam2_checkpoint, device=device, apply_postprocessing=False)

mask_generator_2 = SAM2AutomaticMaskGenerator(
    model=sam2,
    points_per_side=64,
    points_per_batch=128,
    pred_iou_thresh=0.7,
    stability_score_thresh=0.92,
    stability_score_offset=0.7,
    crop_n_layers=1,
    box_nms_thresh=0.7,
    crop_n_points_downscale_factor=2,
    min_mask_region_area=25.0,
    use_m2m=True,
)






def show_anns(orig_img,anns, borders=False, output_dir='', image_path=''):
    if len(anns) == 0:
        return
    image_path = image_path[:-4]
    mask_output_dir = os.path.join(output_dir, image_path)
    os.makedirs(mask_output_dir, exist_ok=True)

    sorted_anns = sorted(anns, key=(lambda x: x['area']), reverse=True)
    combined_mask = np.zeros(orig_img.shape[:2], dtype=np.uint8)
    # set the threshold as 7.5% of the whole amount of original image
    white_pixels_threshold = (orig_img.shape[0] * orig_img.shape[1])* 0.075
    print("debug")

    for i, ann in enumerate(sorted_anns):
        m = ann['segmentation']
        white_pixels = ann["area"]
        if white_pixels > white_pixels_threshold:
            continue

        combined_mask[m > 0] = 1

        # 保存每个单独的掩码

        mask_img = (m * 255).astype(np.uint8)
        output_path = os.path.join(mask_output_dir, f"mask_{i}.png")
        cv2.imwrite(output_path, mask_img)

    print("Saved masks in:", mask_output_dir)
    #ax.imshow(img)
    combined_mask_save_path = os.path.join(output_dir, f"{image_path}_combined.png")
    Image.fromarray((combined_mask * 255).astype(np.uint8)).save(combined_mask_save_path)
    print(f"Combined mask saved at: {combined_mask_save_path}")

    source_img = orig_img
    boundary_img = skimage.segmentation.mark_boundaries(source_img,combined_mask,mode= "thick", color=(1,0,0))

    fig, axs = plt.subplots(1,2,figsize= (12,6))

    axs[0].imshow(boundary_img)
    axs[0].set_title(f"{patient_id}_{image_path}_Boundary Image")
    axs[0].axis("off")

    axs[1].imshow(combined_mask, cmap = "gray")
    axs[1].set_title(f"{patient_id}_{image_path}_Combined Mask")
    axs[1].axis("off")

    plt.tight_layout()

    boundary_and_mask_img_save_path = os.path.join(output_dir, f"{image_path}_boundary_and_mask.png")
    plt.savefig(boundary_and_mask_img_save_path, bbox_inches = "tight")
    plt.show()


    print(f"Saved side by side image at: {boundary_and_mask_img_save_path}")



patient_path = os.path.join(input_dir,f"exam_{patient_id}")
patient_folder = os.path.basename(patient_path)
output_dir = os.path.join(output_dir, patient_folder)

for subpatient_folder in os.listdir(patient_path):
            subpatient_path = os.path.join(patient_path, subpatient_folder)
            if os.path.isdir(subpatient_path):
                subpatient_output_path = os.path.join(output_dir, subpatient_folder)
                os.makedirs(subpatient_output_path, exist_ok=True)

                for image_name in os.listdir(subpatient_path):
                    if image_name.endswith(".png"):
                        image_path = os.path.join(subpatient_path, image_name)
                        image = cv2.imread(image_path)
                        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

                        masks = mask_generator_2.generate(image_rgb)
                        print(f"Generated {len(masks)} masks for {image_name}")

                        show_anns(orig_img=image_rgb,anns=masks, output_dir=subpatient_output_path, image_path=image_name)
# Out:
# using device: cuda
# Generated 15 masks for slice_020_RK.png
# debug
# Saved masks in: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_020_RK
# Combined mask saved at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_020_RK_combined.png
# Saved side by side image at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_020_RK_boundary_and_mask.png
# Generated 11 masks for slice_027_RK.png
# debug
# Saved masks in: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_027_RK
# Combined mask saved at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_027_RK_combined.png
# Saved side by side image at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_027_RK_boundary_and_mask.png
# Generated 5 masks for slice_033_RK.png
# debug
# Saved masks in: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_033_RK
# Combined mask saved at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_033_RK_combined.png
# Saved side by side image at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_033_RK_boundary_and_mask.png
# Generated 8 masks for slice_023_RK.png
# debug
# Saved masks in: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_023_RK
# Combined mask saved at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_023_RK_combined.png
# Saved side by side image at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_023_RK_boundary_and_mask.png
# Generated 3 masks for slice_016_RK.png
# debug
# Saved masks in: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_016_RK
# Combined mask saved at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_016_RK_combined.png
# Saved side by side image at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_016_RK_boundary_and_mask.png
# Generated 9 masks for slice_028_RK.png
# debug
# Saved masks in: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_028_RK
# Combined mask saved at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_028_RK_combined.png
# Saved side by side image at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_028_RK_boundary_and_mask.png
# Generated 6 masks for slice_026_RK.png
# debug
# Saved masks in: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_026_RK
# Combined mask saved at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_026_RK_combined.png
# Saved side by side image at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_026_RK_boundary_and_mask.png
# Generated 5 masks for slice_017_RK.png
# debug
# Saved masks in: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_017_RK
# Combined mask saved at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_017_RK_combined.png
# Saved side by side image at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_017_RK_boundary_and_mask.png
# Generated 9 masks for slice_030_RK.png
# debug
# Saved masks in: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_030_RK
# Combined mask saved at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_030_RK_combined.png
# Saved side by side image at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_030_RK_boundary_and_mask.png
# Generated 11 masks for slice_018_RK.png
# debug
# Saved masks in: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_018_RK
# Combined mask saved at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_018_RK_combined.png
# Saved side by side image at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_018_RK_boundary_and_mask.png
# Generated 17 masks for slice_032_RK.png
# debug
# Saved masks in: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_032_RK
# Combined mask saved at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_032_RK_combined.png
# Saved side by side image at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_032_RK_boundary_and_mask.png
# Generated 15 masks for slice_019_RK.png
# debug
# Saved masks in: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_019_RK
# Combined mask saved at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_019_RK_combined.png
# Saved side by side image at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_019_RK_boundary_and_mask.png
# Generated 6 masks for slice_031_RK.png
# debug
# Saved masks in: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_031_RK
# Combined mask saved at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_031_RK_combined.png
# Saved side by side image at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_031_RK_boundary_and_mask.png
# Generated 4 masks for slice_015_RK.png
# debug
# Saved masks in: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_015_RK
# Combined mask saved at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_015_RK_combined.png
# Saved side by side image at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_015_RK_boundary_and_mask.png
# Generated 10 masks for slice_025_RK.png
# debug
# Saved masks in: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_025_RK
# Combined mask saved at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_025_RK_combined.png
# Saved side by side image at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_025_RK_boundary_and_mask.png
# Generated 13 masks for slice_022_RK.png
# debug
# Saved masks in: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_022_RK
# Combined mask saved at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_022_RK_combined.png
# Saved side by side image at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_022_RK_boundary_and_mask.png
# Generated 15 masks for slice_021_RK.png
# debug
# Saved masks in: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_021_RK
# Combined mask saved at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_021_RK_combined.png
# Saved side by side image at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_021_RK_boundary_and_mask.png
# Generated 12 masks for slice_029_RK.png
# debug
# Saved masks in: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_029_RK
# Combined mask saved at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_029_RK_combined.png
# Saved side by side image at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_029_RK_boundary_and_mask.png
# Generated 14 masks for slice_024_RK.png
# debug
# Saved masks in: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_024_RK
# Combined mask saved at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_024_RK_combined.png
# Saved side by side image at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_024_RK_boundary_and_mask.png
# Generated 2 masks for slice_014_RK.png
# debug
# Saved masks in: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_014_RK
# Combined mask saved at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_014_RK_combined.png
# Saved side by side image at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/RK/slice_014_RK_boundary_and_mask.png
# Generated 10 masks for slice_022_LK.png
# debug
# Saved masks in: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_022_LK
# Combined mask saved at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_022_LK_combined.png
# Saved side by side image at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_022_LK_boundary_and_mask.png
# Generated 19 masks for slice_020_LK.png
# debug
# Saved masks in: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_020_LK
# Combined mask saved at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_020_LK_combined.png
# Saved side by side image at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_020_LK_boundary_and_mask.png
# Generated 9 masks for slice_011_LK.png
# debug
# Saved masks in: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_011_LK
# Combined mask saved at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_011_LK_combined.png
# Saved side by side image at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_011_LK_boundary_and_mask.png
# Generated 24 masks for slice_014_LK.png
# debug
# Saved masks in: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_014_LK
# Combined mask saved at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_014_LK_combined.png
# Saved side by side image at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_014_LK_boundary_and_mask.png
# Generated 23 masks for slice_019_LK.png
# debug
# Saved masks in: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_019_LK
# Combined mask saved at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_019_LK_combined.png
# Saved side by side image at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_019_LK_boundary_and_mask.png
# Generated 23 masks for slice_012_LK.png
# debug
# Saved masks in: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_012_LK
# Combined mask saved at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_012_LK_combined.png
# Saved side by side image at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_012_LK_boundary_and_mask.png
# Generated 25 masks for slice_016_LK.png
# debug
# Saved masks in: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_016_LK
# Combined mask saved at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_016_LK_combined.png
# Saved side by side image at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_016_LK_boundary_and_mask.png
# Generated 39 masks for slice_015_LK.png
# debug
# Saved masks in: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_015_LK
# Combined mask saved at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_015_LK_combined.png
# Saved side by side image at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_015_LK_boundary_and_mask.png
# Generated 22 masks for slice_013_LK.png
# debug
# Saved masks in: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_013_LK
# Combined mask saved at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_013_LK_combined.png
# Saved side by side image at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_013_LK_boundary_and_mask.png
# Generated 4 masks for slice_010_LK.png
# debug
# Saved masks in: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_010_LK
# Combined mask saved at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_010_LK_combined.png
# Saved side by side image at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_010_LK_boundary_and_mask.png
# Generated 5 masks for slice_024_LK.png
# debug
# Saved masks in: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_024_LK
# Combined mask saved at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_024_LK_combined.png
# Saved side by side image at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_024_LK_boundary_and_mask.png
# Generated 22 masks for slice_017_LK.png
# debug
# Saved masks in: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_017_LK
# Combined mask saved at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_017_LK_combined.png
# Saved side by side image at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_017_LK_boundary_and_mask.png
# Generated 15 masks for slice_021_LK.png
# debug
# Saved masks in: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_021_LK
# Combined mask saved at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_021_LK_combined.png
# Saved side by side image at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_021_LK_boundary_and_mask.png
# Generated 2 masks for slice_025_LK.png
# debug
# Saved masks in: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_025_LK
# Combined mask saved at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_025_LK_combined.png
# Saved side by side image at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_025_LK_boundary_and_mask.png
# Generated 10 masks for slice_023_LK.png
# debug
# Saved masks in: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_023_LK
# Combined mask saved at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_023_LK_combined.png
# Saved side by side image at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_023_LK_boundary_and_mask.png
# Generated 18 masks for slice_018_LK.png
# debug
# Saved masks in: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_018_LK
# Combined mask saved at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_018_LK_combined.png
# Saved side by side image at: /home/liao/code/aimarcs-SAM/SAM/sam2/../test_SAM/SAM_2_ORI_second_inference/Hiera_l/exam_019288-01/LK/slice_018_LK_boundary_and_mask.png

# %%
import os
import numpy as np
import torch
import cv2
import matplotlib.pyplot as plt
from sam2.build_sam import build_sam2
from sam2.automatic_mask_generator import SAM2AutomaticMaskGenerator
import skimage
from PIL import Image

sam2_checkpoint = "/home/liao/code/aimarcs-SAM/SAM/sam2/checkpoints/sam2.1_hiera_large.pt"
model_cfg = "configs/sam2.1/sam2.1_hiera_l"


# select the device for computation
if torch.cuda.is_available():
    device = torch.device("cuda")
elif torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")
print(f"using device: {device}")

if device.type == "cuda":
    # use bfloat16 for the entire notebook
    torch.autocast("cuda", dtype=torch.bfloat16).__enter__()
    # turn on tfloat32 for Ampere GPUs (https://pytorch.org/docs/stable/notes/cuda.html#tensorfloat-32-tf32-on-ampere-devices)
    if torch.cuda.get_device_properties(0).major >= 8:
        torch.backends.cuda.matmul.allow_tf32 = True
        torch.backends.cudnn.allow_tf32 = True
elif device.type == "mps":
    print(
        "\nSupport for MPS devices is preliminary. SAM 2 is trained with CUDA and might "
        "give numerically different outputs and sometimes degraded performance on MPS. "
        "See e.g. https://github.com/pytorch/pytorch/issues/84936 for a discussion."
    )
sam2 = build_sam2(model_cfg, sam2_checkpoint, device=device, apply_postprocessing=False)


mask_generator = SAM2AutomaticMaskGenerator(sam2)
mask_generator_2 = SAM2AutomaticMaskGenerator(
    model=sam2,
    points_per_side=128,
    points_per_batch=64,
    pred_iou_thresh=0.7,
    stability_score_thresh=0.92,
    stability_score_offset=0.7,
    crop_n_layers=1,
    box_nms_thresh=0.7,
    crop_n_points_downscale_factor=2,
    min_mask_region_area=25.0,
    use_m2m=True,
)


input_path = "/home/liao/code/aimarcs-SAM/SAM/data/samples_preprocessed/interpolated_images_resized/exam_010044-01/LK/slice_022_LK.png"
image = cv2.imread(input_path)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
print(f"slice image shape: {image_rgb.shape}")

parts = input_path.split(os.sep)
idx = parts.index("interpolated_images_resized")
rel_dir = os.path.join(parts[idx+1],parts[idx+2],parts[idx+3][:-4])

masks = mask_generator_2.generate(image_rgb)

output_base = "/home/liao/code/aimarcs-SAM/SAM/test_SAM/Example"
output_dir = os.path.join(output_base, rel_dir)
os.makedirs(output_dir,exist_ok=True)

sorted_masks = sorted(masks, key=(lambda x: x['area']), reverse=True)
for i, ann in enumerate(sorted_masks):
    m = ann['segmentation']
    print(f"{i} white pixel area: {ann['area']}")
    # 保存每个单独的掩码

    mask_img = (m * 255).astype(np.uint8)
    output_path = os.path.join(output_dir, f"example_mask_{i}.png")
    cv2.imwrite(output_path, mask_img)
# Out:
# using device: cuda
# slice image shape: (1024, 1024, 3)
# 0 white pixel area: 955883
# 1 white pixel area: 50842
# 2 white pixel area: 31457
